# %% [markdown]
# <a href="https://colab.research.google.com/github/ukhyun-lee/stock_market_analysis/blob/main/%EC%A4%91%EA%B8%89/3%EC%9D%BC%EC%B0%A8_%EC%8B%A4%EC%8A%B53.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data = pd.read_excel('sample_data/Dataset_Employes.xlsx')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 254 entries, 0 to 253
# Data columns (total 13 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   id_salarié                 254 non-null    int64
#  1   Contrat                    254 non-null    object
#  2   Durée hebdo                254 non-null    int64
#  3   Salaire base mensuel       254 non-null    float64
#  4   %variable_moyen            254 non-null    int64
#  5   Augmentation               241 non-null    float64
#  6   Promotion                  241 non-null    float64
#  7   Ancienneté_an              254 non-null    float64
#  8   Distance domicile/Travail  254 non-null    int64
#  9   Service                    254 non-null    object
#  10  Niveau de satisfaction     254 non-null    int64
#  11  Type Contrat               254 non-null    object
#  12  Age                        254 non-null    int64
# ...

# %%
data.describe()
# Out:
#        id_salarié  Durée hebdo  Salaire base mensuel  %variable_moyen  \
# count  254.000000   254.000000            254.000000       254.000000
# mean   127.838583    33.862205           5324.339070        19.968504
# std     73.904981     3.214454           2514.924462        11.510735
# min      1.000000    24.000000           1059.760000         0.000000
# 25%     64.250000    35.000000           3101.994975        10.000000
# 50%    127.500000    35.000000           5084.625000        19.000000
# 75%    191.750000    35.000000           7466.929150        30.000000
# max    256.000000    35.000000           9999.383300        40.000000
#
#        Augmentation   Promotion  Ancienneté_an  Distance domicile/Travail  \
# count    241.000000  241.000000     254.000000                 254.000000
# mean       0.518672    0.514523      13.111024                  38.326772
# std        0.500691    0.500829       7.014730                  19.811152
# ...

# %% [markdown]
# # index는 x축이다.

# %%
data.Contrat.value_counts().plot.bar()
# Out:
# <Axes: >

# %%
data.Contrat.value_counts().plot.barh()
# Out:
# <Axes: >

# %%
data.Contrat.value_counts().plot.line()
# Out:
# <Axes: >

# %%
data.boxplot()
# Out:
# <Axes: >

# %%
import seaborn as sns     #=> padas 기본

# %%
tips = sns.load_dataset('tips')

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.lineplot(data, x='Age', y='Niveau de satisfaction')
# Out:
# <Axes: xlabel='Age', ylabel='Niveau de satisfaction'>

# %%
sns.lineplot(data, x='Age', y='Niveau de satisfaction', hue='Contrat')
# Out:
# <Axes: xlabel='Age', ylabel='Niveau de satisfaction'>

# %%
sns.countplot(data, x='Service')    # 숫자값 X
# Out:
# <Axes: xlabel='Service', ylabel='count'>

# %%
sns.catplot(data, x='Service', y='Salaire base mensuel', hue='Contrat' )

# %%
# c.f)

# %%
data_csv = pd.read_csv('sample_data/Dataset_Employes.csv', encoding='latin-1')

# %%
data_csv
# Out:
#                                                  id_salarié;Contrat;Durée hebdo;Salaire base mensuel;%variable_moyen;Augmentation;Promotion;Ancienneté_an;Distance domicile/Travail;Service;Niveau de satisfaction;Type Contrat;Age
# 1;CDI;35;9894   7;13;0;0;22                                              5;69;Technique;60;Cadre;46
# 2;CDI;35;4296   7167;39;0;1;10                                       8;32;Technique;39;Non Cadre;55
# 3;CDI;35;3705   2167;29;1;1;13;68;RH;62;Cadre;52                                                NaN
# 4;CDI;35;1697   15;17;1;0;21                                         7;59;Technique;98;Non Cadre;58
# 5;CDD;35;2848   3;15;1;0;3                                                 3;15;R&D;81;Non Cadre;39
# ...                                                                                             ...
# 252;CDI;35;7304 2667;17;1;0;7                                            9;59;Technique;34;Cadre;41
# ...
