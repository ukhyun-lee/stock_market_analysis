# %% [markdown]
# <a href="https://colab.research.google.com/github/ukhyun-lee/stock_market_analysis/blob/main/%EC%A4%91%EA%B8%89/16%EC%9D%BC%EC%B0%A8_%EC%8B%A4%EC%8A%B52.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -U geopandas
# Out:
# Requirement already satisfied: geopandas in c:\users\sunde\anaconda3\lib\site-packages (0.12.2)
# Collecting geopandas
#   Downloading geopandas-0.13.2-py3-none-any.whl (1.1 MB)
#      ---------------------------------------- 1.1/1.1 MB 17.2 MB/s eta 0:00:00
# Requirement already satisfied: packaging in c:\users\sunde\anaconda3\lib\site-packages (from geopandas) (22.0)
# Requirement already satisfied: pandas>=1.1.0 in c:\users\sunde\anaconda3\lib\site-packages (from geopandas) (2.0.3)
# Requirement already satisfied: shapely>=1.7.1 in c:\users\sunde\anaconda3\lib\site-packages (from geopandas) (2.0.1)
# Requirement already satisfied: pyproj>=3.0.1 in c:\users\sunde\anaconda3\lib\site-packages (from geopandas) (3.5.0)
# Requirement already satisfied: fiona>=1.8.19 in c:\users\sunde\anaconda3\lib\site-packages (from geopandas) (1.9.3)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\sunde\anaconda3\lib\site-packages (from fiona>=1.8.19->geopandas) (22.1.0)
# Requirement already satisfied: click~=8.0 in c:\users\sunde\anaconda3\lib\site-packages (from fiona>=1.8.19->geopandas) (8.0.4)
# Requirement already satisfied: munch>=2.3.2 in c:\users\sunde\anaconda3\lib\site-packages (from fiona>=1.8.19->geopandas) (2.5.0)
# Requirement already satisfied: certifi in c:\users\sunde\anaconda3\lib\site-packages (from fiona>=1.8.19->geopandas) (2022.12.7)
# Requirement already satisfied: click-plugins>=1.0 in c:\users\sunde\anaconda3\lib\site-packages (from fiona>=1.8.19->geopandas) (1.1.1)
# Requirement already satisfied: cligj>=0.5 in c:\users\sunde\anaconda3\lib\site-packages (from fiona>=1.8.19->geopandas) (0.7.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\sunde\anaconda3\lib\site-packages (from pandas>=1.1.0->geopandas) (2.8.2)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\sunde\anaconda3\lib\site-packages (from pandas>=1.1.0->geopandas) (1.23.5)
# Requirement already satisfied: pytz>=2020.1 in c:\users\sunde\anaconda3\lib\site-packages (from pandas>=1.1.0->geopandas) (2022.7)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\sunde\anaconda3\lib\site-packages (from pandas>=1.1.0->geopandas) (2023.3)
# Requirement already satisfied: colorama in c:\users\sunde\anaconda3\lib\site-packages (from click~=8.0->fiona>=1.8.19->geopandas) (0.4.6)
# Requirement already satisfied: six in c:\users\sunde\anaconda3\lib\site-packages (from munch>=2.3.2->fiona>=1.8.19->geopandas) (1.16.0)
# Installing collected packages: geopandas
#   Attempting uninstall: geopandas
#     Found existing installation: geopandas 0.12.2
#     Uninstalling geopandas-0.12.2:
#       Successfully uninstalled geopandas-0.12.2
# Successfully installed geopandas-0.13.2
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\sunde\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\sunde\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\sunde\anaconda3\lib\site-packages)
#     WARNING: Ignoring invalid distribution -rotobuf (c:\users\sunde\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\sunde\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\sunde\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\sunde\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\sunde\anaconda3\lib\site-packages)

# %%
import geopandas as gpd

# %%
gpd.datasets.available
# Out:
# ['naturalearth_cities', 'naturalearth_lowres', 'nybb']

# %%
gpd.datasets.get_path('naturalearth_lowres')
# Out:
# C:\Users\sunde\AppData\Local\Temp\ipykernel_28048\4200470739.py:1: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_lowres' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
#   gpd.datasets.get_path('naturalearth_lowres')
# 'C:\\Users\\sunde\\anaconda3\\lib\\site-packages\\geopandas\\datasets\\naturalearth_lowres\\naturalearth_lowres.shp'

# %%
gpd.read_parquet

# %%
gpd.read_postgis

# %%
data = gpd.read_file(gpd.datasets.get_path('nybb'))
# Out:
# C:\Users\sunde\AppData\Local\Temp\ipykernel_28048\3837587743.py:1: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'nybb' data from the geodatasets package.
#
# from geodatasets import get_path
# path_to_file = get_path('nybb')
#
#   data = gpd.read_file(gpd.datasets.get_path('nybb'))

# %%
data.geom_type.value_counts()
# Out:
# MultiPolygon    5
# Name: count, dtype: int64

# %%
data.area
# Out:
# 0    1.623822e+09
# 1    3.045214e+09
# 2    1.937478e+09
# 3    6.364712e+08
# 4    1.186926e+09
# dtype: float64

# %%
data.bounds
# Out:
#            minx           miny          maxx           maxy
# 0  9.131751e+05  120121.881254  9.705701e+05  175708.962036
# 1  9.946086e+05  136681.776184  1.067383e+06  231157.996399
# 2  9.726197e+05  146772.031799  1.030453e+06  208564.104004
# 3  9.710135e+05  188082.322388  1.010066e+06  259547.770386
# 4  1.002623e+06  225426.884583  1.049167e+06  272844.293640

# %%
data.boundary
# Out:
# 0    MULTILINESTRING ((970217.022 145643.332, 97022...
# 1    MULTILINESTRING ((1029606.077 156073.814, 1029...
# 2    MULTILINESTRING ((1021176.479 151374.797, 1021...
# 3    MULTILINESTRING ((981219.056 188655.316, 98094...
# 4    MULTILINESTRING ((1012821.806 229228.265, 1012...
# dtype: geometry

# %%
data.centroid
# Out:
# 0     POINT (941639.450 150931.991)
# 1    POINT (1034578.078 197116.604)
# 2     POINT (998769.115 174169.761)
# 3     POINT (993336.965 222451.437)
# 4    POINT (1021174.790 249937.980)
# dtype: geometry

# %%
data.distance()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 data.distance()
#
# TypeError: GeoPandasBase.distance() missing 1 required positional argument: 'other'

# %%
data = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
# Out:
# C:\Users\sunde\AppData\Local\Temp\ipykernel_28048\1249246206.py:1: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_lowres' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
#   data = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

# %%
data.plot()
# Out:
# <Axes: >

# %%
data.geometry
# Out:
# 0      MULTIPOLYGON (((180.00000 -16.06713, 180.00000...
# 1      POLYGON ((33.90371 -0.95000, 34.07262 -1.05982...
# 2      POLYGON ((-8.66559 27.65643, -8.66512 27.58948...
# 3      MULTIPOLYGON (((-122.84000 49.00000, -122.9742...
# 4      MULTIPOLYGON (((-122.84000 49.00000, -120.0000...
#                              ...
# 172    POLYGON ((18.82982 45.90887, 18.82984 45.90888...
# 173    POLYGON ((20.07070 42.58863, 19.80161 42.50009...
# 174    POLYGON ((20.59025 41.85541, 20.52295 42.21787...
# 175    POLYGON ((-61.68000 10.76000, -61.10500 10.890...
# 176    POLYGON ((30.83385 3.50917, 29.95350 4.17370, ...
# Name: geometry, Length: 177, dtype: geometry

# %%
data['area'] = data.area
# Out:
# C:\Users\sunde\AppData\Local\Temp\ipykernel_28048\2440170118.py:1: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   data['area'] = data.area

# %%
data
# Out:
#          pop_est      continent                      name iso_a3  gdp_md_est  \
# 0       889953.0        Oceania                      Fiji    FJI        5496
# 1     58005463.0         Africa                  Tanzania    TZA       63177
# 2       603253.0         Africa                 W. Sahara    ESH         907
# 3     37589262.0  North America                    Canada    CAN     1736425
# 4    328239523.0  North America  United States of America    USA    21433226
# ..           ...            ...                       ...    ...         ...
# 172    6944975.0         Europe                    Serbia    SRB       51475
# 173     622137.0         Europe                Montenegro    MNE        5542
# 174    1794248.0         Europe                    Kosovo    -99        7926
# 175    1394973.0  North America       Trinidad and Tobago    TTO       24269
# 176   11062113.0         Africa                  S. Sudan    SSD       11998
#
#                                               geometry  \
# 0    MULTIPOLYGON (((180.00000 -16.06713, 180.00000...
# 1    POLYGON ((33.90371 -0.95000, 34.07262 -1.05982...
# 2    POLYGON ((-8.66559 27.65643, -8.66512 27.58948...
# 3    MULTIPOLYGON (((-122.84000 49.00000, -122.9742...
# 4    MULTIPOLYGON (((-122.84000 49.00000, -120.0000...
# ..                                                 ...
# 172  POLYGON ((18.82982 45.90887, 18.82984 45.90888...
# 173  POLYGON ((20.07070 42.58863, 19.80161 42.50009...
# 174  POLYGON ((20.59025 41.85541, 20.52295 42.21787...
# 175  POLYGON ((-61.68000 10.76000, -61.10500 10.890...
# 176  POLYGON ((30.83385 3.50917, 29.95350 4.17370, ...
#
#                         centroid         area
# 0    POINT (163.85316 -17.31631)     1.639511
# 1      POINT (34.75299 -6.25773)    76.301964
# 2     POINT (-12.13783 24.29117)     8.603984
# 3     POINT (-98.14238 61.46908)  1712.995228
# 4    POINT (-112.59944 45.70563)  1122.281921
# ..                           ...          ...
# 172    POINT (20.81965 44.23304)     8.604719
# 173    POINT (19.28618 42.78904)     1.479321
# 174    POINT (20.89536 42.57937)     1.231641
# 175   POINT (-61.33037 10.42824)     0.639000
# 176     POINT (30.19862 7.29289)    51.196106
#
# [177 rows x 8 columns]

# %%
data[data.continent=='Africa'].plot('area', legend=True)
# Out:
# <Axes: >

# %%
# !pip install -U mapclassify
# Out:
# Collecting mapclassify
#   Downloading mapclassify-2.6.0-py3-none-any.whl (40 kB)
#      ---------------------------------------- 40.8/40.8 kB 1.9 MB/s eta 0:00:00
# Requirement already satisfied: scipy>=1.0 in c:\users\sunde\anaconda3\lib\site-packages (from mapclassify) (1.10.0)
# Requirement already satisfied: scikit-learn in c:\users\sunde\anaconda3\lib\site-packages (from mapclassify) (1.2.1)
# Requirement already satisfied: pandas>=1.0 in c:\users\sunde\anaconda3\lib\site-packages (from mapclassify) (2.0.3)
# Requirement already satisfied: networkx in c:\users\sunde\anaconda3\lib\site-packages (from mapclassify) (2.8.4)
# Requirement already satisfied: numpy>=1.3 in c:\users\sunde\anaconda3\lib\site-packages (from mapclassify) (1.23.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\sunde\anaconda3\lib\site-packages (from pandas>=1.0->mapclassify) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\sunde\anaconda3\lib\site-packages (from pandas>=1.0->mapclassify) (2022.7)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\sunde\anaconda3\lib\site-packages (from pandas>=1.0->mapclassify) (2023.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\sunde\anaconda3\lib\site-packages (from scikit-learn->mapclassify) (2.2.0)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\sunde\anaconda3\lib\site-packages (from scikit-learn->mapclassify) (1.1.1)
# Requirement already satisfied: six>=1.5 in c:\users\sunde\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.0->mapclassify) (1.16.0)
# Installing collected packages: mapclassify
# Successfully installed mapclassify-2.6.0
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\sunde\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\sunde\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\sunde\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\sunde\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\sunde\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\sunde\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\sunde\anaconda3\lib\site-packages)

# %%
data.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9058760d504640a0aebe5a52bad17b14 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9058760d504640a0aebe5a52bad17b14&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9058760d504640a0aebe5a52bad17b14 = L.map(
#                 &quot;map_9058760d504640a0aebe5a52bad17b14&quot;,
#                 {
#                     center: [-3.1774349999999956, 2.842170943040401e-14],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_9058760d504640a0aebe5a52bad17b14);
#
#
#
#
#
#             var tile_layer_cff54fada4b183fdf025458ba3edbe1f = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_9058760d504640a0aebe5a52bad17b14);
#
#
#             map_9058760d504640a0aebe5a52bad17b14.fitBounds(
#                 [[-90.0, -180.0], [83.64513000000001, 180.00000000000006]],
#                 {}
#             );
#
#
#         function geo_json_de50cf2b8428d1a20aae30c45d9db343_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_de50cf2b8428d1a20aae30c45d9db343_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_de50cf2b8428d1a20aae30c45d9db343_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_de50cf2b8428d1a20aae30c45d9db343_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_de50cf2b8428d1a20aae30c45d9db343_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_de50cf2b8428d1a20aae30c45d9db343.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_de50cf2b8428d1a20aae30c45d9db343_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_de50cf2b8428d1a20aae30c45d9db343 = L.geoJson(null, {
#                 onEachFeature: geo_json_de50cf2b8428d1a20aae30c45d9db343_onEachFeature,
#
#                 style: geo_json_de50cf2b8428d1a20aae30c45d9db343_styler,
#                 pointToLayer: geo_json_de50cf2b8428d1a20aae30c45d9db343_pointToLayer
#         });
#
#         function geo_json_de50cf2b8428d1a20aae30c45d9db343_add (data) {
#             geo_json_de50cf2b8428d1a20aae30c45d9db343
#                 .addData(data)
#                 .addTo(map_9058760d504640a0aebe5a52bad17b14);
#         }
#             geo_json_de50cf2b8428d1a20aae30c45d9db343_add({&quot;bbox&quot;: [-180.0, -90.0, 180.00000000000006, 83.64513000000001], &quot;features&quot;: [{&quot;bbox&quot;: [-180.0, -18.28799, 180.0, -16.020882256741224], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[[180.0, -16.067132663642447], [180.0, -16.555216566639196], [179.36414266196414, -16.801354076946883], [178.72505936299711, -17.01204167436804], [178.59683859511713, -16.639150000000004], [179.0966093629971, -16.433984277547403], [179.4135093629971, -16.379054277547404], [180.0, -16.067132663642447]]], [[[178.12557, -17.50481], [178.3736, -17.33992], [178.71806, -17.62846], [178.55271, -18.15059], [177.93266000000003, -18.28799], [177.381

# %%
data['centroid'] = data.centroid
# Out:
# C:\Users\sunde\AppData\Local\Temp\ipykernel_28048\2022448725.py:1: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   data['centroid'] = data.centroid

# %%
data2 = data.set_geometry('centroid')

# %%
data2.plot()
# Out:
# <Axes: >

# %%
data2.geometry
# Out:
# 0      POINT (163.85316 -17.31631)
# 1        POINT (34.75299 -6.25773)
# 2       POINT (-12.13783 24.29117)
# 3       POINT (-98.14238 61.46908)
# 4      POINT (-112.59944 45.70563)
#                   ...
# 172      POINT (20.81965 44.23304)
# 173      POINT (19.28618 42.78904)
# 174      POINT (20.89536 42.57937)
# 175     POINT (-61.33037 10.42824)
# 176       POINT (30.19862 7.29289)
# Name: centroid, Length: 177, dtype: geometry

# %%
seoul = gpd.read_file('seoul_municipalities_geo_simple.json')

# %%
seoul.plot()
# Out:
# <Axes: >

# %%
seoul
# Out:
#      code  name         name_eng base_year  \
# 0   11250   강동구      Gangdong-gu      2013
# 1   11240   송파구        Songpa-gu      2013
# 2   11230   강남구       Gangnam-gu      2013
# 3   11220   서초구        Seocho-gu      2013
# 4   11210   관악구        Gwanak-gu      2013
# 5   11200   동작구       Dongjak-gu      2013
# 6   11190  영등포구  Yeongdeungpo-gu      2013
# 7   11180   금천구     Geumcheon-gu      2013
# 8   11170   구로구          Guro-gu      2013
# 9   11160   강서구       Gangseo-gu      2013
# 10  11150   양천구     Yangcheon-gu      2013
# 11  11140   마포구          Mapo-gu      2013
# 12  11130  서대문구     Seodaemun-gu      2013
# 13  11120   은평구     Eunpyeong-gu      2013
# 14  11110   노원구         Nowon-gu      2013
# 15  11100   도봉구        Dobong-gu      2013
# 16  11090   강북구       Gangbuk-gu      2013
# 17  11080   성북구      Seongbuk-gu      2013
# 18  11070   중랑구      Jungnang-gu      2013
# 19  11060  동대문구    Dongdaemun-gu      2013
# 20  11050   광진구      Gwangjin-gu      2013
# 21  11040   성동구     Seongdong-gu      2013
# 22  11030   용산구       Yongsan-gu      2013
# 23  11020    중구          Jung-gu      2013
# 24  11010   종로구        Jongno-gu      2013
#
#                                              geometry
# 0   POLYGON ((127.11520 37.55753, 127.11880 37.557...
# 1   POLYGON ((127.06907 37.52228, 127.07496 37.520...
# 2   POLYGON ((127.05867 37.52630, 127.06907 37.522...
# 3   POLYGON ((127.01397 37.52504, 127.01918 37.520...
# 4   POLYGON ((126.98368 37.47386, 126.98464 37.469...
# 5   POLYGON ((126.98224 37.50931, 126.98242 37.501...
# 6   POLYGON ((126.89185 37.54737, 126.90281 37.541...
# 7   POLYGON ((126.90156 37.47754, 126.90277 37.476...
# 8   POLYGON ((126.82688 37.50549, 126.83122 37.505...
# 9   POLYGON ((126.85984 37.57185, 126.85950 37.568...
# 10  POLYGON ((126.82423 37.53788, 126.82890 37.539...
# 11  POLYGON ((126.90522 37.57410, 126.90370 37.572...
# 12  POLYGON ((126.95248 37.60509, 126.95481 37.603...
# 13  POLYGON ((126.97389 37.62950, 126.97135 37.627...
# 14  POLYGON ((127.10782 37.61804, 127.10362 37.617...
# 15  POLYGON ((127.05288 37.68424, 127.05403 37.682...
# 16  POLYGON ((127.01040 37.68189, 127.01073 37.676...
# 17  POLYGON ((126.97718 37.62860, 126.97941 37.630...
# 18  POLYGON ((127.07351 37.61284, 127.08325 37.616...
# 19  POLYGON ((127.02527 37.57525, 127.03122 37.579...
# 20  POLYGON ((127.08069 37.56906, 127.08553 37.568...
# 21  POLYGON ((127.02547 37.56894, 127.03182 37.567...
# 22  POLYGON ((127.01071 37.54118, 127.01044 37.539...
# 23  POLYGON ((127.02547 37.56894, 127.02572 37.562...
# 24  POLYGON ((126.97389 37.62950, 126.97718 37.628...

# %%
seoul.plot('code')
# Out:
# <Axes: >

# %%
seoul.explore('code', legend=False)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f9fb1670c9d89f022a967fb7b6dd287e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f9fb1670c9d89f022a967fb7b6dd287e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f9fb1670c9d89f022a967fb7b6dd287e = L.map(
#                 &quot;map_f9fb1670c9d89f022a967fb7b6dd287e&quot;,
#                 {
#                     center: [37.562169358000396, 126.97621921972123],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_f9fb1670c9d89f022a967fb7b6dd287e);
#
#
#
#
#
#             var tile_layer_b0519b8ff65c5827773bbb04d28c51e9 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_f9fb1670c9d89f022a967fb7b6dd287e);
#
#
#             map_f9fb1670c9d89f022a967fb7b6dd287e.fitBounds(
#                 [[37.42574929824175, 126.76700465024426], [37.698589417759045, 127.18543378919821]],
#                 {}
#             );
#
#
#         function geo_json_7de26f5c92b6b4ce9a12405a379706ea_styler(feature) {
#             switch(feature.id) {
#                 case &quot;0&quot;: case &quot;1&quot;:
#                     return {&quot;color&quot;: &quot;#9edae5&quot;, &quot;fillColor&quot;: &quot;#9edae5&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;2&quot;:
#                     return {&quot;color&quot;: &quot;#17becf&quot;, &quot;fillColor&quot;: &quot;#17becf&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;3&quot;:
#                     return {&quot;color&quot;: &quot;#dbdb8d&quot;, &quot;fillColor&quot;: &quot;#dbdb8d&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;4&quot;:
#                     return {&quot;color&quot;: &quot;#bcbd22&quot;, &quot;fillColor&quot;: &quot;#bcbd22&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;7&quot;:
#                     return {&quot;color&quot;: &quot;#7f7f7f&quot;, &quot;fillColor&quot;: &quot;#7f7f7f&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;8&quot;:
#                     return {&quot;color&quot;: &quot;#f7b6d2&quot;, &quot;fillColor&quot;: &quot;#f7b6d2&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;9&quot;:
#                     return {&quot;color&quot;: &quot;#e377c2&quot;, &quot;fillColor&quot;: &quot;#e377c2&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;10&quot;:
#                     return {&quot;color&quot;: &quot;#c49c94&quot;, &quot;fillColor&quot;: &quot;#c49c94&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;11&quot;: case &quot;12&quot;:
#                     return {&quot;color&quot;: &quot;#8c564b&quot;, &quot;fillColor&quot;: &quot;#8c564b&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;13&quot;:
#                     return {&quot;color&quot;: &quot;#c5b0d5&quot;, &quot;fillColor&quot;: &quot;#c5b0d5&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;14&quot;:
#                     return {&quot;color&quot;: &quot;#9467bd&quot;, &quot;fillColor&quot;: &quot;#9467bd&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;15&quot;:
#                     return {&quot;color&quot;: &quot;#ff9896&quot;, &quot;fillColor&quot;: &quot;#ff9896&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;16&quot;:
#                     return {&quot;color&quot;: &quot;#d62728&quot;, &quot;fillColor&quot;: &quot;#d62728&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;17&quot;: case &quot;18&quot;:
#                     return {&quot;color&quot;: &quot;#98df8a&quot;, &quot;fillColor&quot;: &quot;#98df8a&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;19&quot;:
#                     return {&quot;color&quot;: &quot;#2ca02c&quot;, &quot;fillColor&quot;: &quot;#2ca02c&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};

# %%
seoul_topo = gpd.read_file('seoul_municipalities_topo_simple.json')

# %%
seoul_topo.plot()
# Out:
# <Axes: >

# %%
seoul_topo.loc[0]
# Out:
# id                                                         NaN
# code                                                     11250
# name                                                       강동구
# name_eng                                           Gangdong-gu
# base_year                                                 2013
# geometry     POLYGON ((127.11521665689241 37.55753272454938...
# Name: 0, dtype: object

# %%
seoul_topo.iloc[0]
# Out:
# id                                                         NaN
# code                                                     11250
# name                                                       강동구
# name_eng                                           Gangdong-gu
# base_year                                                 2013
# geometry     POLYGON ((127.11521665689241 37.55753272454938...
# Name: 0, dtype: object

# %%
seoul.cx[126.8:127,:]
# Out:
#      code  name         name_eng base_year  \
# 3   11220   서초구        Seocho-gu      2013
# 4   11210   관악구        Gwanak-gu      2013
# 5   11200   동작구       Dongjak-gu      2013
# 6   11190  영등포구  Yeongdeungpo-gu      2013
# 7   11180   금천구     Geumcheon-gu      2013
# 8   11170   구로구          Guro-gu      2013
# 9   11160   강서구       Gangseo-gu      2013
# 10  11150   양천구     Yangcheon-gu      2013
# 11  11140   마포구          Mapo-gu      2013
# 12  11130  서대문구     Seodaemun-gu      2013
# 13  11120   은평구     Eunpyeong-gu      2013
# 16  11090   강북구       Gangbuk-gu      2013
# 17  11080   성북구      Seongbuk-gu      2013
# 22  11030   용산구       Yongsan-gu      2013
# 23  11020    중구          Jung-gu      2013
# 24  11010   종로구        Jongno-gu      2013
#
#                                              geometry
# 3   POLYGON ((127.01397 37.52504, 127.01918 37.520...
# 4   POLYGON ((126.98368 37.47386, 126.98464 37.469...
# 5   POLYGON ((126.98224 37.50931, 126.98242 37.501...
# 6   POLYGON ((126.89185 37.54737, 126.90281 37.541...
# 7   POLYGON ((126.90156 37.47754, 126.90277 37.476...
# 8   POLYGON ((126.82688 37.50549, 126.83122 37.505...
# 9   POLYGON ((126.85984 37.57185, 126.85950 37.568...
# 10  POLYGON ((126.82423 37.53788, 126.82890 37.539...
# 11  POLYGON ((126.90522 37.57410, 126.90370 37.572...
# 12  POLYGON ((126.95248 37.60509, 126.95481 37.603...
# 13  POLYGON ((126.97389 37.62950, 126.97135 37.627...
# 16  POLYGON ((127.01040 37.68189, 127.01073 37.676...
# 17  POLYGON ((126.97718 37.62860, 126.97941 37.630...
# 22  POLYGON ((127.01071 37.54118, 127.01044 37.539...
# 23  POLYGON ((127.02547 37.56894, 127.02572 37.562...
# 24  POLYGON ((126.97389 37.62950, 126.97718 37.628...
