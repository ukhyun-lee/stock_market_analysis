# %% [markdown]
# <a href="https://colab.research.google.com/github/ukhyun-lee/stock_market_analysis/blob/main/%EC%A4%91%EA%B8%89/16%EC%9D%BC%EC%B0%A8_%EC%8B%A4%EC%8A%B52.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -U geopandas

# %%
import geopandas as gpd

# %%
gpd.datasets.available
# Out:
# ['naturalearth_lowres', 'naturalearth_cities', 'nybb']

# %%
gpd.datasets.get_path('naturalearth_lowres')
# Out:
# <ipython-input-54-a4eec129949f>:1: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_lowres' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
#   gpd.datasets.get_path('naturalearth_lowres')
# '/usr/local/lib/python3.10/dist-packages/geopandas/datasets/naturalearth_lowres/naturalearth_lowres.shp'

# %%
data = gpd.read_file(gpd.datasets.get_path('naturalearth_cities'))
# Out:
# <ipython-input-6-60d1aaaf82cf>:1: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_cities' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
#   data = gpd.read_file(gpd.datasets.get_path('naturalearth_cities'))

# %%
data = gpd.read_file(gpd.datasets.get_path('nybb'))
# Out:
# <ipython-input-9-369f547c93b5>:1: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'nybb' data from the geodatasets package.
#
# from geodatasets import get_path
# path_to_file = get_path('nybb')
#
#   data = gpd.read_file(gpd.datasets.get_path('nybb'))

# %% [markdown]
# #geometry

# %%
data.geometry
# Out:
# 0    MULTIPOLYGON (((970217.022 145643.332, 970227....
# 1    MULTIPOLYGON (((1029606.077 156073.814, 102957...
# 2    MULTIPOLYGON (((1021176.479 151374.797, 102100...
# 3    MULTIPOLYGON (((981219.056 188655.316, 980940....
# 4    MULTIPOLYGON (((1012821.806 229228.265, 101278...
# Name: geometry, dtype: geometry

# %%
data.geom_type.value_counts()
# Out:
# MultiPolygon    5
# dtype: int64

# %%
data.geometry.value_counts()
# Out:
# POINT (12.45339 41.90328)      1
# POINT (68.77388 38.56004)      1
# POINT (-61.51703 10.65200)     1
# POINT (9.51667 47.13372)       1
# POINT (31.20000 -26.46667)     1
#                               ..
# POINT (88.36913 22.56958)      1
# POINT (-43.21212 -22.90731)    1
# POINT (-46.62697 -23.55673)    1
# POINT (151.21255 -33.87137)    1
# POINT (114.18306 22.30693)     1
# Name: geometry, Length: 243, dtype: int64

# %%
data.area
# Out:
# 0    1.623822e+09
# 1    3.045214e+09
# 2    1.937478e+09
# 3    6.364712e+08
# 4    1.186926e+09
# dtype: float64

# %%
data.bounds
# Out:
#            minx           miny          maxx           maxy
# 0  9.131751e+05  120121.881254  9.705701e+05  175708.962036
# 1  9.946086e+05  136681.776184  1.067383e+06  231157.996399
# 2  9.726197e+05  146772.031799  1.030453e+06  208564.104004
# 3  9.710135e+05  188082.322388  1.010066e+06  259547.770386
# 4  1.002623e+06  225426.884583  1.049167e+06  272844.293640

# %%
data.boundary
# Out:
# 0    MULTILINESTRING ((970217.022 145643.332, 97022...
# 1    MULTILINESTRING ((1029606.077 156073.814, 1029...
# 2    MULTILINESTRING ((1021176.479 151374.797, 1021...
# 3    MULTILINESTRING ((981219.056 188655.316, 98094...
# 4    MULTILINESTRING ((1012821.806 229228.265, 1012...
# dtype: geometry

# %%
data.centroid
# Out:
# 0     POINT (941639.450 150931.991)
# 1    POINT (1034578.078 197116.604)
# 2     POINT (998769.115 174169.761)
# 3     POINT (993336.965 222451.437)
# 4    POINT (1021174.790 249937.980)
# dtype: geometry

# %%
data = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
# Out:
# <ipython-input-18-e9aaddf74f64>:1: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_lowres' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
#   data = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

# %%
data.plot()
# Out:
# <Axes: >

# %%
data.geometry
# Out:
# 0      MULTIPOLYGON (((180.00000 -16.06713, 180.00000...
# 1      POLYGON ((33.90371 -0.95000, 34.07262 -1.05982...
# 2      POLYGON ((-8.66559 27.65643, -8.66512 27.58948...
# 3      MULTIPOLYGON (((-122.84000 49.00000, -122.9742...
# 4      MULTIPOLYGON (((-122.84000 49.00000, -120.0000...
#                              ...
# 172    POLYGON ((18.82982 45.90887, 18.82984 45.90888...
# 173    POLYGON ((20.07070 42.58863, 19.80161 42.50009...
# 174    POLYGON ((20.59025 41.85541, 20.52295 42.21787...
# 175    POLYGON ((-61.68000 10.76000, -61.10500 10.890...
# 176    POLYGON ((30.83385 3.50917, 29.95350 4.17370, ...
# Name: geometry, Length: 177, dtype: geometry

# %%
data['area'] = data.area
# Out:
# <ipython-input-43-a77912d26f76>:1: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   data['area'] = data.area

# %%
data

# %%
data[data.continent=='Africa'].plot(legend=True)   ## 좌표값만 그림
# Out:
# <Axes: >

# %%
data[data.continent=='Africa'].plot('area', legend=True)
# Out:
# <Axes: >

# %%
# !pip install -U mapclassify
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.8/40.8 kB 2.0 MB/s eta 0:00:00
# ...

# %%
data.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
data['centroid'] = data.centroid
# Out:
# <ipython-input-21-3bd81d31f81f>:1: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   data['centroid'] = data.centroid

# %%
data
# Out:
#          pop_est      continent                      name iso_a3  gdp_md_est  \
# 0       889953.0        Oceania                      Fiji    FJI        5496
# 1     58005463.0         Africa                  Tanzania    TZA       63177
# 2       603253.0         Africa                 W. Sahara    ESH         907
# 3     37589262.0  North America                    Canada    CAN     1736425
# 4    328239523.0  North America  United States of America    USA    21433226
# ..           ...            ...                       ...    ...         ...
# 172    6944975.0         Europe                    Serbia    SRB       51475
# 173     622137.0         Europe                Montenegro    MNE        5542
# 174    1794248.0         Europe                    Kosovo    -99        7926
# 175    1394973.0  North America       Trinidad and Tobago    TTO       24269
# 176   11062113.0         Africa                  S. Sudan    SSD       11998
#
# ...

# %% [markdown]
# ## 판다스와 거의 똑같다. geometry 제외하고

# %%
data2 = data.set_geometry('centroid')

# %%
data2.plot()

# %%
data2.geometry
# Out:
# 0      POINT (163.85316 -17.31631)
# 1        POINT (34.75299 -6.25773)
# 2       POINT (-12.13783 24.29117)
# 3       POINT (-98.14238 61.46908)
# 4      POINT (-112.59944 45.70563)
#                   ...
# 172      POINT (20.81965 44.23304)
# 173      POINT (19.28618 42.78904)
# 174      POINT (20.89536 42.57937)
# 175     POINT (-61.33037 10.42824)
# 176       POINT (30.19862 7.29289)
# Name: centroid, Length: 177, dtype: geometry

# %%
seoul = gpd.read_file('sample_data/seoul_municipalities_geo_simple.json')

# %%
seoul.plot()
# Out:
# <Axes: >

# %%
seoul.plot('code')
# Out:
# <Axes: >

# %%
seoul.explore('code', legend=False)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
seoul_topo = gpd.read_file('sample_data/seoul_municipalities_topo_simple.json')

# %%
seoul_topo.plot()
# Out:
# <Axes: >

# %%
seoul_topo.area
# Out:
# 0     0.002600
# 1     0.003428
# 2     0.003922
# 3     0.004877
# 4     0.003039
# 5     0.001775
# 6     0.002204
# 7     0.001279
# 8     0.002020
# 9     0.004373
# 10    0.001819
# 11    0.002509
# 12    0.001777
# 13    0.003194
# 14    0.003632
# 15    0.002120
# 16    0.002426
# 17    0.002484
# 18    0.001838
# 19    0.001475
# 20    0.001804
# 21    0.001690
# 22    0.002158
# 23    0.001032
# 24    0.002437
# dtype: float64

# %%
seoul_topo.centroid
# Out:
# 0     POINT (127.14904 37.54839)
# 1     POINT (127.11741 37.50228)
# 2     POINT (127.06479 37.49447)
# 3     POINT (127.03322 37.47095)
# 4     POINT (126.94807 37.46441)
# 5     POINT (126.95435 37.49685)
# 6     POINT (126.91205 37.51739)
# 7     POINT (126.90338 37.45769)
# 8     POINT (126.85892 37.49175)
# 9     POINT (126.82657 37.55827)
# 10    POINT (126.85835 37.52199)
# 11    POINT (126.91193 37.55545)
# 12    POINT (126.94111 37.57465)
# 13    POINT (126.93098 37.61703)
# 14    POINT (127.07743 37.64932)
# 15    POINT (127.03449 37.66635)
# 16    POINT (127.01317 37.64073)
# 17    POINT (127.02007 37.60303)
# 18    POINT (127.09511 37.59516)
# 19    POINT (127.05740 37.57919)
# 20    POINT (127.08877 37.54381)
# 21    POINT (127.04337 37.54846)
# 22    POINT (126.98227 37.52964)
# 23    POINT (126.99787 37.55727)
# 24    POINT (126.97982 37.59147)
# dtype: geometry

# %%
seoul_topo.loc[0]
# Out:
# id                                                         NaN
# code                                                     11250
# name                                                       강동구
# name_eng                                           Gangdong-gu
# base_year                                                 2013
# geometry     POLYGON ((127.11521665689241 37.55753272454938...
# Name: 0, dtype: object

# %%
seoul_topo.iloc[0]
# Out:
# id                                                         NaN
# code                                                     11250
# name                                                       강동구
# name_eng                                           Gangdong-gu
# base_year                                                 2013
# geometry     POLYGON ((127.11521665689241 37.55753272454938...
# Name: 0, dtype: object

# %%
seoul.cx[126.8:127, :]   #좌표계 기반
# Out:
#      code  name         name_eng base_year  \
# 3   11220   서초구        Seocho-gu      2013
# 4   11210   관악구        Gwanak-gu      2013
# 5   11200   동작구       Dongjak-gu      2013
# 6   11190  영등포구  Yeongdeungpo-gu      2013
# 7   11180   금천구     Geumcheon-gu      2013
# 8   11170   구로구          Guro-gu      2013
# 9   11160   강서구       Gangseo-gu      2013
# 10  11150   양천구     Yangcheon-gu      2013
# 11  11140   마포구          Mapo-gu      2013
# 12  11130  서대문구     Seodaemun-gu      2013
# 13  11120   은평구     Eunpyeong-gu      2013
# 16  11090   강북구       Gangbuk-gu      2013
# 17  11080   성북구      Seongbuk-gu      2013
# 22  11030   용산구       Yongsan-gu      2013
# 23  11020    중구          Jung-gu      2013
# 24  11010   종로구        Jongno-gu      2013
#
#                                              geometry
# 3   POLYGON ((127.01397 37.52504, 127.01918 37.520...
# 4   POLYGON ((126.98368 37.47386, 126.98464 37.469...
# 5   POLYGON ((126.98224 37.50931, 126.98242 37.501...
# ...

# %% [markdown]
# #  GeoPandas(geopandas.org)
#
# ## Plotting with CartoPy and GeoPandas
#
# ## 스파셜 어널리시스의 허브 역할
#
# ## pySAL
#
# ## 판다스와 geo판다스 연결시킬 수 있음
