# %% [markdown]
# <a href="https://colab.research.google.com/github/ukhyun-lee/stock_market_analysis/blob/main/%EC%A4%91%EA%B8%89/2%EC%9D%BC%EC%B0%A8_%EC%8B%A4%EC%8A%B54.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data = pd.read_csv('sample_data/daegu.csv')
# Out:
# <ipython-input-2-2c62199f1750>:1: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv('sample_data/daegu.csv')

# %%
data.head()
# Out:
#                  상가업소번호      상호명  지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드 상권업종중분류명  \
# 0  MA0101202210A0034750    더벤티대구  NaN        I2       음식      I212    비알코올
# 1  MA0101202210A0003881  엉클몽키테니스  NaN        R1   예술·스포츠      R103  스포츠 서비스
# 2  MA0101202210A0101134    무아브로우  NaN        S2    수리·개인      S207    이용·미용
# 3  MA0101202210A0078919   베스트홀덤펍  NaN        I2       음식      I211       주점
# 4  MA0101202210A0055790    홍천뚝배기  NaN        I2       음식      I201       한식
#
#   상권업종소분류코드 상권업종소분류명 표준산업분류코드  ...                     건물관리번호  건물명  \
# 0    I21201       카페   I56221  ...  2714010100104980007000001  NaN
# 1    R10312     테니스장   R91199  ...  2729011500114450004013792  NaN
# 2    S20702   피부 관리실   S96113  ...  2711015600109170008015104  NaN
# 3    I21103   생맥주 전문   I56213  ...  2729011400105540000001917  NaN
# 4    I20102  국/탕/찌개류   I56111  ...  2723011100113130000000002  NaN
#
#                  도로명주소   구우편번호  신우편번호  동정보  층정보  호정보          경도         위도
# ...

# %%
data.head()
data.tail()
data.sample()
# Out:
#                      상가업소번호          상호명  지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드  \
# 78279  MA010120220813274799  피자나라치킨공주성당점  NaN        I2       음식      I210
#
#       상권업종중분류명 상권업종소분류코드 상권업종소분류명 표준산업분류코드  ...                     건물관리번호  \
# 78279    기타 간이    I21003       피자   I56192  ...  2729010100107070012028963
#
#        건물명              도로명주소   구우편번호  신우편번호  동정보 층정보  호정보          경도  \
# 78279  NaN  대구광역시 달서구 당산동길 33  704918  42654  NaN   1  NaN  128.546429
#
#               위도
# 78279  35.845304
#
# [1 rows x 39 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 111472 entries, 0 to 111471
# Data columns (total 39 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   상가업소번호     111472 non-null  object
#  1   상호명        111472 non-null  object
#  2   지점명        260 non-null     object
#  3   상권업종대분류코드  111472 non-null  object
#  4   상권업종대분류명   111472 non-null  object
#  5   상권업종중분류코드  111472 non-null  object
#  6   상권업종중분류명   111472 non-null  object
#  7   상권업종소분류코드  111472 non-null  object
#  8   상권업종소분류명   111472 non-null  object
#  9   표준산업분류코드   111472 non-null  object
#  10  표준산업분류명    111472 non-null  object
#  11  시도코드       111472 non-null  int64
#  12  시도명        111472 non-null  object
#  13  시군구코드      111472 non-null  int64
#  14  시군구명       111472 non-null  object
#  15  행정동코드      111472 non-null  int64
#  16  행정동명       111472 non-null  object
#  17  법정동코드      111472 non-null  int64
#  18  법정동명       111472 non-null  object
# ...

# %%
data.filter(like='코드')
# Out:
#        상권업종대분류코드 상권업종중분류코드 상권업종소분류코드 표준산업분류코드  시도코드  시군구코드     행정동코드  \
# 0             I2      I212    I21201   I56221    27  27140  27140520
# 1             R1      R103    R10312   R91199    27  27290  27290625
# 2             S2      S207    S20702   S96113    27  27110  27110640
# 3             I2      I211    I21103   I56213    27  27290  27290590
# 4             I2      I201    I20102   I56111    27  27230  27230630
# ...          ...       ...       ...      ...   ...    ...       ...
# 111467        I2      I212    I21201   I56221    27  27710  27710256
# 111468        I2      I201    I20102   I56111    27  27290  27290555
# 111469        I2      I201    I20101   I56111    27  27200  27200640
# 111470        I2      I201    I20101   I56111    27  27290  27290640
# 111471        L1      L102    L10203   L68221    27  27200  27200586
#
#              법정동코드                 지번코드  대지구분코드         도로명코드
# 0       2714010100  2714010100104980007       1  271403141014
# ...

# %%
data.columns
# Out:
# Index(['상가업소번호', '상호명', '지점명', '상권업종대분류코드', '상권업종대분류명', '상권업종중분류코드',
#        '상권업종중분류명', '상권업종소분류코드', '상권업종소분류명', '표준산업분류코드', '표준산업분류명', '시도코드',
#        '시도명', '시군구코드', '시군구명', '행정동코드', '행정동명', '법정동코드', '법정동명', '지번코드',
#        '대지구분코드', '대지구분명', '지번본번지', '지번부번지', '지번주소', '도로명코드', '도로명', '건물본번지',
#        '건물부번지', '건물관리번호', '건물명', '도로명주소', '구우편번호', '신우편번호', '동정보', '층정보',
#        '호정보', '경도', '위도'],
#       dtype='object')

# %%
data.dtypes
# Out:
# 상가업소번호        object
# 상호명           object
# 지점명           object
# 상권업종대분류코드     object
# 상권업종대분류명      object
# 상권업종중분류코드     object
# 상권업종중분류명      object
# 상권업종소분류코드     object
# 상권업종소분류명      object
# 표준산업분류코드      object
# 표준산업분류명       object
# 시도코드           int64
# 시도명           object
# 시군구코드          int64
# 시군구명          object
# 행정동코드          int64
# 행정동명          object
# 법정동코드          int64
# 법정동명          object
# 지번코드           int64
# 대지구분코드         int64
# 대지구분명         object
# 지번본번지        float64
# 지번부번지        float64
# 지번주소          object
# 도로명코드          int64
# 도로명           object
# 건물본번지          int64
# 건물부번지        float64
# 건물관리번호        object
# 건물명           object
# 도로명주소         object
# 구우편번호          int64
# 신우편번호          int64
# 동정보          float64
# 층정보           object
# 호정보          float64
# 경도           float64
# 위도           float64
# dtype: object

# %%
data.dtypes.index
# Out:
# Index(['상가업소번호', '상호명', '지점명', '상권업종대분류코드', '상권업종대분류명', '상권업종중분류코드',
#        '상권업종중분류명', '상권업종소분류코드', '상권업종소분류명', '표준산업분류코드', '표준산업분류명', '시도코드',
#        '시도명', '시군구코드', '시군구명', '행정동코드', '행정동명', '법정동코드', '법정동명', '지번코드',
#        '대지구분코드', '대지구분명', '지번본번지', '지번부번지', '지번주소', '도로명코드', '도로명', '건물본번지',
#        '건물부번지', '건물관리번호', '건물명', '도로명주소', '구우편번호', '신우편번호', '동정보', '층정보',
#        '호정보', '경도', '위도'],
#       dtype='object')

# %%
data[['구우편번호','신우편번호']]
# Out:
#          구우편번호  신우편번호
# 0       701818  41200
# 1       704817  42790
# 2       700802  41957
# 3       704914  42695
# 4       702842  41544
# ...        ...    ...
# 111467  711814  42930
# 111468  704753  42688
# 111469  705803  42450
# 111470  704820  42736
# 111471  705816  42402
#
# [111472 rows x 2 columns]

# %%
data.filter(like='우편번호')
# Out:
#          구우편번호  신우편번호
# 0       701818  41200
# 1       704817  42790
# 2       700802  41957
# 3       704914  42695
# 4       702842  41544
# ...        ...    ...
# 111467  711814  42930
# 111468  704753  42688
# 111469  705803  42450
# 111470  704820  42736
# 111471  705816  42402
#
# [111472 rows x 2 columns]

# %%
data[data['상권업종대분류명']=='음식']
# Out:
#                       상가업소번호          상호명  지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드  \
# 0       MA0101202210A0034750        더벤티대구  NaN        I2       음식      I212
# 3       MA0101202210A0078919       베스트홀덤펍  NaN        I2       음식      I211
# 4       MA0101202210A0055790        홍천뚝배기  NaN        I2       음식      I201
# 5       MA010120220805430823       오느른케이크  NaN        I2       음식      I210
# 10      MA010120220805431497         자담치킨  NaN        I2       음식      I210
# ...                      ...          ...  ...       ...      ...       ...
# 111459  MA0101202302A0102722      전복배말칼국수  NaN        I2       음식      I201
# 111467  MA0101202302A0072447        퍼스트커피  NaN        I2       음식      I212
# 111468  MA0101202302A0041111  효자동설렁탕월드마크점  NaN        I2       음식      I201
# 111469  MA0101202302A0049422         리리푸드  NaN        I2       음식      I201
# 111470  MA0101202302A0079461         일월식당  NaN        I2       음식      I201
#
# ...

# %%
data[data['상권업종소분류명']=='카페']
# Out:
#                       상가업소번호      상호명  지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드  \
# 0       MA0101202210A0034750    더벤티대구  NaN        I2       음식      I212
# 31      MA010120220805434416     로우동인  NaN        I2       음식      I212
# 54      MA010120220805434743     올제커피  NaN        I2       음식      I212
# 56      MA010120220805435246      다즐링  NaN        I2       음식      I212
# 61      MA010120220805438000     오아시스  NaN        I2       음식      I212
# ...                      ...      ...  ...       ...      ...       ...
# 111419  MA0101202302A0053895      더램브  NaN        I2       음식      I212
# 111426  MA0101202302A0059947     매스커피  NaN        I2       음식      I212
# 111434  MA0101202302A0057834     허밍14  NaN        I2       음식      I212
# 111453  MA0101202302A0060638  빽다방대구팔달  노원점        I2       음식      I212
# 111467  MA0101202302A0072447    퍼스트커피  NaN        I2       음식      I212
#
#        상권업종중분류명 상권업종소분류코드 상권업종소분류명 표준산업분류코드  ...                     건물관리번호  \
# ...

# %%
data[data['상권업종소분류명'].isin(['카페','테니스장'])]
# Out:
#                       상가업소번호      상호명  지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드  \
# 0       MA0101202210A0034750    더벤티대구  NaN        I2       음식      I212
# 1       MA0101202210A0003881  엉클몽키테니스  NaN        R1   예술·스포츠      R103
# 31      MA010120220805434416     로우동인  NaN        I2       음식      I212
# 54      MA010120220805434743     올제커피  NaN        I2       음식      I212
# 56      MA010120220805435246      다즐링  NaN        I2       음식      I212
# ...                      ...      ...  ...       ...      ...       ...
# 111419  MA0101202302A0053895      더램브  NaN        I2       음식      I212
# 111426  MA0101202302A0059947     매스커피  NaN        I2       음식      I212
# 111434  MA0101202302A0057834     허밍14  NaN        I2       음식      I212
# 111453  MA0101202302A0060638  빽다방대구팔달  노원점        I2       음식      I212
# 111467  MA0101202302A0072447    퍼스트커피  NaN        I2       음식      I212
#
#        상권업종중분류명 상권업종소분류코드 상권업종소분류명 표준산업분류코드  ...                     건물관리번호  \
# ...

# %% [markdown]
# #python and / or

# %%
4 or 3
# Out:
# 4

# %%
True + True
# Out:
# 2

# %%
True + False
# Out:
# 1

# %%
#True / False가 숫자라면 참과 거짓은?

# %%
#=>  존재론적 관점에서

# %%
if 0:
  print('True')
else:
  print('False')
# Out:
# False

# %%
if "":
  print('True')
else:
  print('False')
# Out:
# False

# %%
if "1":
  print('True')
else:
  print('False')
# Out:
# True

# %%
if {}:
  print('True')
else:
  print('False')
# Out:
# False

# %%
if None:
  print('True')
else:
  print('False')
# Out:
# False

# %%
#and
#앞에 것이 참이면 뒤에 것
#앞에 것이 거짓이면 앞에 것

# %%
"" and 3
# Out:
# ''

# %%
0 and [12, 3,]
# Out:
# 0

# %%
#or 
#앞에 것이 참이면 앞에 것
#앞에 것이 거짓이면 뒤에 것

# %%
"" or 3
# Out:
# 3

# %%
'a' in 'abc'
# Out:
# True

# %%
1 in [2,3,1] #membership
# Out:
# True

# %%
import seaborn as sns
tips = sns.load_dataset('tips')

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
#pd.read_csv

# %%
tips[tips.sex == 'Male']
# Out:
#      total_bill   tip   sex smoker  day    time  size
# 1         10.34  1.66  Male     No  Sun  Dinner     3
# 2         21.01  3.50  Male     No  Sun  Dinner     3
# 3         23.68  3.31  Male     No  Sun  Dinner     2
# 5         25.29  4.71  Male     No  Sun  Dinner     4
# 6          8.77  2.00  Male     No  Sun  Dinner     2
# ..          ...   ...   ...    ...  ...     ...   ...
# 236       12.60  1.00  Male    Yes  Sat  Dinner     2
# 237       32.83  1.17  Male    Yes  Sat  Dinner     2
# 239       29.03  5.92  Male     No  Sat  Dinner     3
# 241       22.67  2.00  Male    Yes  Sat  Dinner     2
# 242       17.82  1.75  Male     No  Sat  Dinner     2
#
# [157 rows x 7 columns]

# %%
male_tips = tips[tips.sex == 'Male'].copy()

# %%
male_tips
# Out:
#      total_bill   tip   sex smoker  day    time  size
# 1         10.34  1.66  Male     No  Sun  Dinner     3
# 2         21.01  3.50  Male     No  Sun  Dinner     3
# 3         23.68  3.31  Male     No  Sun  Dinner     2
# 5         25.29  4.71  Male     No  Sun  Dinner     4
# 6          8.77  2.00  Male     No  Sun  Dinner     2
# ..          ...   ...   ...    ...  ...     ...   ...
# 236       12.60  1.00  Male    Yes  Sat  Dinner     2
# 237       32.83  1.17  Male    Yes  Sat  Dinner     2
# 239       29.03  5.92  Male     No  Sat  Dinner     3
# 241       22.67  2.00  Male    Yes  Sat  Dinner     2
# 242       17.82  1.75  Male     No  Sat  Dinner     2
#
# [157 rows x 7 columns]

# %%
male_tips.at[3, 'total_bill'] = 50

# %%
male_tips
# Out:
#      total_bill   tip   sex smoker  day    time  size
# 1         10.34  1.66  Male     No  Sun  Dinner     3
# 2         21.01  3.50  Male     No  Sun  Dinner     3
# 3         50.00  3.31  Male     No  Sun  Dinner     2
# 5         25.29  4.71  Male     No  Sun  Dinner     4
# 6          8.77  2.00  Male     No  Sun  Dinner     2
# ..          ...   ...   ...    ...  ...     ...   ...
# 236       12.60  1.00  Male    Yes  Sat  Dinner     2
# 237       32.83  1.17  Male    Yes  Sat  Dinner     2
# 239       29.03  5.92  Male     No  Sat  Dinner     3
# 241       22.67  2.00  Male    Yes  Sat  Dinner     2
# 242       17.82  1.75  Male     No  Sat  Dinner     2
#
# [157 rows x 7 columns]

# %%
male_tips[male_tips.day == 'Sun'][['tip']].mean()
# Out:
# tip    3.220345
# dtype: float64

# %%
male_tips[male_tips.day == 'Sun'][['tip']].quantile()  #통계값
# Out:
# tip    3.085
# Name: 0.5, dtype: float64

# %%
male_tips[male_tips.day == 'Sun'][['tip']]
# Out:
#       tip
# 1    1.66
# 2    3.50
# 3    3.31
# 5    4.71
# 6    2.00
# 7    3.12
# 8    1.96
# 9    3.23
# 10   1.71
# 12   1.57
# 13   3.00
# 15   3.92
# 17   3.71
# 41   2.54
# 42   3.06
# 43   1.32
# 44   5.60
# 45   3.00
# 46   5.00
# 47   6.00
# 48   2.05
# 49   3.00
# 50   2.50
# 53   1.56
# 54   4.34
# 55   3.51
# 112  4.00
# 113  2.55
# 116  5.07
# 150  2.50
# 151  2.00
# 152  2.74
# 153  2.00
# 154  2.00
# 156  5.00
# 159  2.00
# 160  3.50
# 161  2.50
# 163  2.00
# 165  3.48
# 166  2.24
# 167  4.50
# 172  5.15
# 173  3.18
# 174  4.00
# 175  3.11
# 176  2.00
# 177  2.00
# 179  3.55
# 180  3.68
# 181  5.65
# 182  3.50
# 183  6.50
# 184  3.00
# 185  5.00
# 187  2.00
# 189  4.00
# 190  1.50

# %%
male_tips[['tip','day']]   #dataframe => dataframe에서 배웠던 테크닉도 그대로 쓸 수 있음 => chaining
# Out:
#       tip  day
# 1    1.66  Sun
# 2    3.50  Sun
# 3    3.31  Sun
# 5    4.71  Sun
# 6    2.00  Sun
# ..    ...  ...
# 236  1.00  Sat
# 237  1.17  Sat
# 239  5.92  Sat
# 241  2.00  Sat
# 242  1.75  Sat
#
# [157 rows x 2 columns]
