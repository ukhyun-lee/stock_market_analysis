# %% [markdown]
# <a href="https://colab.research.google.com/github/ukhyun-lee/stock_market_analysis/blob/main/%EC%A4%91%EA%B8%89/6%EC%9D%BC%EC%B0%A8_%EC%8B%A4%EC%8A%B53.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns

# %%
mpg = sns.load_dataset('mpg')

# %%
mpg
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# ...

# %%
mpg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    392 non-null    float64
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model_year    398 non-null    int64
#  7   origin        398 non-null    object
#  8   name          398 non-null    object
# dtypes: float64(4), int64(3), object(2)
# memory usage: 28.1+ KB

# %%
mpg[mpg.horsepower.isnull()]
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 32   25.0          4          98.0         NaN    2046          19.0
# 126  21.0          6         200.0         NaN    2875          17.0
# 330  40.9          4          85.0         NaN    1835          17.3
# 336  23.6          4         140.0         NaN    2905          14.3
# 354  34.5          4         100.0         NaN    2320          15.8
# 374  23.0          4         151.0         NaN    3035          20.5
#
#      model_year  origin                  name
# 32           71     usa            ford pinto
# 126          74     usa         ford maverick
# 330          80  europe  renault lecar deluxe
# 336          80     usa    ford mustang cobra
# 354          81  europe           renault 18i
# 374          82     usa        amc concord dl

# %%
mpg.horsepower.isnull().sum()
# Out:
# 6

# %%
mpg.horsepower.isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 393    False
# 394    False
# 395    False
# 396    False
# 397    False
# Name: horsepower, Length: 398, dtype: bool

# %%
mpg.isnull().any()
# Out:
# mpg             False
# cylinders       False
# displacement    False
# horsepower       True
# weight          False
# acceleration    False
# model_year      False
# origin          False
# name            False
# dtype: bool

# %%
mpg.columns[mpg.isnull().any()]
# Out:
# Index(['horsepower'], dtype='object')

# %%
import missingno as mino

# %%
mino.matrix(mpg)
# Out:
# <Axes: >

# %%
mino.bar(mpg)
# Out:
# <Axes: >

# %%
mino.dendrogram(mpg)
# Out:
# <Axes: >

# %%
mino.heatmap(mpg)
# Out:
# <Axes: >

# %% [markdown]
# #missing data
# - missing data > row, column

# %%
mpg.dropna()  #row
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# ...

# %%
mpg.dropna(axis=1) #column
# Out:
#       mpg  cylinders  displacement  weight  acceleration  model_year  origin  \
# 0    18.0          8         307.0    3504          12.0          70     usa
# 1    15.0          8         350.0    3693          11.5          70     usa
# 2    18.0          8         318.0    3436          11.0          70     usa
# 3    16.0          8         304.0    3433          12.0          70     usa
# 4    17.0          8         302.0    3449          10.5          70     usa
# ..    ...        ...           ...     ...           ...         ...     ...
# 393  27.0          4         140.0    2790          15.6          82     usa
# 394  44.0          4          97.0    2130          24.6          82  europe
# 395  32.0          4         135.0    2295          11.6          82     usa
# 396  28.0          4         120.0    2625          18.6          82     usa
# 397  31.0          4         119.0    2720          19.4          82     usa
#
#                           name
# ...

# %% [markdown]
# # missing data 값 채우는 기술  => impute

# %%
i = mpg[mpg.horsepower.isnull()].index

# %%
i
# Out:
# Int64Index([32, 126, 330, 336, 354, 374], dtype='int64')

# %%
mpg.fillna(0).loc[i]
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 32   25.0          4          98.0         0.0    2046          19.0
# 126  21.0          6         200.0         0.0    2875          17.0
# 330  40.9          4          85.0         0.0    1835          17.3
# 336  23.6          4         140.0         0.0    2905          14.3
# 354  34.5          4         100.0         0.0    2320          15.8
# 374  23.0          4         151.0         0.0    3035          20.5
#
#      model_year  origin                  name
# 32           71     usa            ford pinto
# 126          74     usa         ford maverick
# 330          80  europe  renault lecar deluxe
# 336          80     usa    ford mustang cobra
# 354          81  europe           renault 18i
# 374          82     usa        amc concord dl

# %%
mpg.horsepower.mean()
# Out:
# 104.46938775510205

# %%
mpg.fillna(104)
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# ...

# %%
mpg.fillna(method='backfill').loc[30:35]
# Out:
#      mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 30  28.0          4         140.0        90.0    2264          15.5
# 31  25.0          4         113.0        95.0    2228          14.0
# 32  25.0          4          98.0       100.0    2046          19.0
# 33  19.0          6         232.0       100.0    2634          13.0
# 34  16.0          6         225.0       105.0    3439          15.5
# 35  17.0          6         250.0       100.0    3329          15.5
#
#     model_year origin                       name
# 30          71    usa        chevrolet vega 2300
# 31          71  japan              toyota corona
# 32          71    usa                 ford pinto
# 33          71    usa                amc gremlin
# 34          71    usa  plymouth satellite custom
# 35          71    usa  chevrolet chevelle malibu

# %%
mpg.fillna(method='ffill').loc[30:35]
# Out:
#      mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 30  28.0          4         140.0        90.0    2264          15.5
# 31  25.0          4         113.0        95.0    2228          14.0
# 32  25.0          4          98.0        95.0    2046          19.0
# 33  19.0          6         232.0       100.0    2634          13.0
# 34  16.0          6         225.0       105.0    3439          15.5
# 35  17.0          6         250.0       100.0    3329          15.5
#
#     model_year origin                       name
# 30          71    usa        chevrolet vega 2300
# 31          71  japan              toyota corona
# 32          71    usa                 ford pinto
# 33          71    usa                amc gremlin
# 34          71    usa  plymouth satellite custom
# 35          71    usa  chevrolet chevelle malibu

# %% [markdown]
# #필수 전처리 해야 (아래처럼 문자열 때문 error) => sklearn에서 자동 처리해줌 => NaN 때문에 error

# %%
from sklearn.neighbors import KNeighborsRegressor

# %%
 knn = KNeighborsRegressor()

# %%
knn.fit(mpg.iloc[:,1:], mpg.mpg)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-37-ca7db5b37017> in <cell line: 1>()
# ----> 1 knn.fit(mpg.iloc[:,1:], mpg.mpg)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/neighbors/_regression.py in fit(self, X, y)
#     215         self._validate_params()
#     216
# --> 217         return self._fit(X, y)
#     218
#     219     def predict(self, X):
#
# /usr/local/lib/python3.10/dist-packages/sklearn/neighbors/_base.py in _fit(self, X, y)
#     452         if self._get_tags()["requires_y"]:
#     453             if not isinstance(X, (KDTree, BallTree, NeighborsBase)):
# --> 454                 X, y = self._validate_data(
#     455                     X, y, accept_sparse="csr", multi_output=True, order="C"
#     456                 )
#
# ...

# %%
mpg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    392 non-null    float64
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model_year    398 non-null    int64
# dtypes: float64(4), int64(3)
# memory usage: 21.9 KB

# %%
mpg.drop(columns=['origin','name'], inplace=True)

# %%
knn.fit(mpg.iloc[:,1:], mpg.mpg)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-45-ca7db5b37017> in <cell line: 1>()
# ----> 1 knn.fit(mpg.iloc[:,1:], mpg.mpg)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/neighbors/_regression.py in fit(self, X, y)
#     215         self._validate_params()
#     216
# --> 217         return self._fit(X, y)
#     218
#     219     def predict(self, X):
#
# /usr/local/lib/python3.10/dist-packages/sklearn/neighbors/_base.py in _fit(self, X, y)
#     452         if self._get_tags()["requires_y"]:
#     453             if not isinstance(X, (KDTree, BallTree, NeighborsBase)):
# --> 454                 X, y = self._validate_data(
#     455                     X, y, accept_sparse="csr", multi_output=True, order="C"
#     456                 )
#
# ...
