# %% [markdown]
# <a href="https://colab.research.google.com/github/ukhyun-lee/stock_market_analysis/blob/main/AI%EC%A4%91%EA%B8%89/AI%EC%8B%A4%EC%8A%B5_CNN1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #딥러닝 과정
# ##데이터수집
# ##데이터전처리
# ##모델학습(3-1.모델생성, 3-2.층구성, 3-3.모델환경설정, 3-4.모델학습)
# ##모델검증 및 평가(검증데이터 및 테스트 데이터 활용)
# ##모델예측(실제 데이터를 활용한 예측)

# %%
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Dense

# %%
import numpy as np
import pandas as pd
from google.colab import files

# %%
from google.colab import files

uploaded = files.upload()
data_set = np.loadtxt("ThoraricSurgery3.csv", delimiter=",")
print(data_set)
# Out:
#      <input type="file" id="files-c8cc01a0-1d00-4f67-989e-3f83a100922a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c8cc01a0-1d00-4f67-989e-3f83a100922a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
data_set1 = pd.read_csv('sample_data/ThoraricSurgery3.csv', delimiter=',', header=None)

# %%
data_set
# Out:
# array([[ 1.  ,  2.88,  2.16, ...,  0.  , 60.  ,  0.  ],
#        [ 2.  ,  3.4 ,  1.88, ...,  0.  , 51.  ,  0.  ],
#        [ 2.  ,  2.76,  2.08, ...,  0.  , 59.  ,  0.  ],
#        ...,
#        [ 2.  ,  3.04,  2.08, ...,  0.  , 52.  ,  0.  ],
#        [ 2.  ,  1.96,  1.68, ...,  0.  , 79.  ,  0.  ],
#        [ 2.  ,  4.72,  3.56, ...,  0.  , 51.  ,  0.  ]])

# %%
x = data_set[:, 0:16]

# %%
y = data_set[:, 16]

# %%
#모델 생성 및 층 구성
model = Sequential()

# %%
#입력, 은닉층(뉴런개수(출력수), 특징입력 개수, 활성화함수)
model.add(Dense(30, input_dim=16, activation='relu'))

# %%
#출력층
model.add(Dense(1, activation='sigmoid'))

# %%
#모델 환경설정(손실함수, 옵티마이저, 평가지표)
model.compile(loss='binary_crossentropy', optimizer='adam', metrics='accuracy')

# %%
#모델 학습(에포크, 배치사이즈는 사용자가 직접 넣는 값(하이퍼파라미터))
model.fit(x, y, epochs=10, batch_size=16)
# Out:
# Epoch 1/10
# 30/30 [==============================] - 1s 2ms/step - loss: 0.7712 - accuracy: 0.8234
# Epoch 2/10
# 30/30 [==============================] - 0s 2ms/step - loss: 0.4688 - accuracy: 0.8426
# Epoch 3/10
# 30/30 [==============================] - 0s 2ms/step - loss: 0.4351 - accuracy: 0.8511
# Epoch 4/10
# 30/30 [==============================] - 0s 2ms/step - loss: 0.4300 - accuracy: 0.8511
# Epoch 5/10
# 30/30 [==============================] - 0s 3ms/step - loss: 0.4337 - accuracy: 0.8511
# Epoch 6/10
# 30/30 [==============================] - 0s 2ms/step - loss: 0.4243 - accuracy: 0.8511
# Epoch 7/10
# 30/30 [==============================] - 0s 3ms/step - loss: 0.4260 - accuracy: 0.8511
# Epoch 8/10
# 30/30 [==============================] - 0s 2ms/step - loss: 0.4194 - accuracy: 0.8511
# Epoch 9/10
# 30/30 [==============================] - 0s 2ms/step - loss: 0.4143 - accuracy: 0.8511
# Epoch 10/10
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('sample_data/pima-indians-diabetes3.csv')

# %%
df.head(5)
# Out:
#    pregnant  plasma  pressure  thickness  insulin   bmi  pedigree  age  \
# 0         6     148        72         35        0  33.6     0.627   50
# 1         1      85        66         29        0  26.6     0.351   31
# 2         8     183        64          0        0  23.3     0.672   32
# 3         1      89        66         23       94  28.1     0.167   21
# 4         0     137        40         35      168  43.1     2.288   33
#
#    diabetes
# 0         1
# 1         0
# 2         1
# 3         0
# 4         1

# %%
df
# Out:
#      pregnant  plasma  pressure  thickness  insulin   bmi  pedigree  age  \
# 0           6     148        72         35        0  33.6     0.627   50
# 1           1      85        66         29        0  26.6     0.351   31
# 2           8     183        64          0        0  23.3     0.672   32
# 3           1      89        66         23       94  28.1     0.167   21
# 4           0     137        40         35      168  43.1     2.288   33
# ..        ...     ...       ...        ...      ...   ...       ...  ...
# 763        10     101        76         48      180  32.9     0.171   63
# 764         2     122        70         27        0  36.8     0.340   27
# 765         5     121        72         23      112  26.2     0.245   30
# 766         1     126        60          0        0  30.1     0.349   47
# 767         1      93        70         31        0  30.4     0.315   23
#
#      diabetes
# 0           1
# 1           0
# 2           1
# 3           0
# ...

# %%
df["diabetes"].value_counts()
# Out:
# 0    500
# 1    268
# Name: diabetes, dtype: int64

# %%
df.describe()
# Out:
#          pregnant      plasma    pressure   thickness     insulin         bmi  \
# count  768.000000  768.000000  768.000000  768.000000  768.000000  768.000000
# mean     3.845052  120.894531   69.105469   20.536458   79.799479   31.992578
# std      3.369578   31.972618   19.355807   15.952218  115.244002    7.884160
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      1.000000   99.000000   62.000000    0.000000    0.000000   27.300000
# 50%      3.000000  117.000000   72.000000   23.000000   30.500000   32.000000
# 75%      6.000000  140.250000   80.000000   32.000000  127.250000   36.600000
# max     17.000000  199.000000  122.000000   99.000000  846.000000   67.100000
#
#          pedigree         age    diabetes
# count  768.000000  768.000000  768.000000
# mean     0.471876   33.240885    0.348958
# std      0.331329   11.760232    0.476951
# min      0.078000   21.000000    0.000000
# 25%      0.243750   24.000000    0.000000
# ...

# %%
df.corr()
# Out:
#            pregnant    plasma  pressure  thickness   insulin       bmi  \
# pregnant   1.000000  0.129459  0.141282  -0.081672 -0.073535  0.017683
# plasma     0.129459  1.000000  0.152590   0.057328  0.331357  0.221071
# pressure   0.141282  0.152590  1.000000   0.207371  0.088933  0.281805
# thickness -0.081672  0.057328  0.207371   1.000000  0.436783  0.392573
# insulin   -0.073535  0.331357  0.088933   0.436783  1.000000  0.197859
# bmi        0.017683  0.221071  0.281805   0.392573  0.197859  1.000000
# pedigree  -0.033523  0.137337  0.041265   0.183928  0.185071  0.140647
# age        0.544341  0.263514  0.239528  -0.113970 -0.042163  0.036242
# diabetes   0.221898  0.466581  0.065068   0.074752  0.130548  0.292695
#
#            pedigree       age  diabetes
# pregnant  -0.033523  0.544341  0.221898
# plasma     0.137337  0.263514  0.466581
# pressure   0.041265  0.239528  0.065068
# thickness  0.183928 -0.113970  0.074752
# insulin    0.185071 -0.042163  0.130548
# ...

# %% [markdown]
# #인사이트 도출. 예측과 모델링, 변수(특징)선택, 이상치 탐지

# %%
colormap = plt.cm.gist_heat   #그래프의 색상 구성을 정합니다.  c.f) viridis, plasma, inferno, magma

# %%
plt.figure(figsize=(12,12))

# %% [markdown]
# 계수 추정의 불안정성: 다중공선성으로 인해 독립 변수 간에 상관관계가 높을 경우, 모델이 해당 변수들의 영향을 정확히 추정하기 어려워집니다. 계수의 변동성이 커지며, 예측력이 떨어질 수 있습니다.
#
# 계수의 부호 변화: 다중공선성 때문에 독립 변수들 간의 상관관계가 높으면 계수의 부호가 예측과 반대로 나올 수 있습니다. 이는 의미 없는 결과를 나타낼 수 있습니다.
#
# 모델 해석의 어려움: 다중공선성이 있는 모델은 어떤 독립 변수가 종속 변수에 어떤 영향을 미치는지 명확하게 파악하기 어렵습니다. 변수들 간에 상호작용이 복잡해질 수 있습니다.

# %%
#                      셀간격,         표현최대값범위                              값표현여부
sns.heatmap(df.corr(), linewidths=0.1, vmax=0.5, cmap=colormap, linecolor='white', annot=True)
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('ThoraricSurgery3.csv', delimiter=',', header=None)

x = df.iloc[:, 0:16]
y = df.iloc[:, 16]

colormap = plt.cm.gist_heat
plt.figure(figsize=(24, 24))

sns.heatmap(df.corr(), linewidths=0.1, vmax=0.5, cmap=colormap, linecolor='white', annot=True)
plt.show()

# plt.hist(x=[df.bmi[df.diabetes==0], df.bmi[df.diabetes==1]], bins=10, histtype='barstacked', label=['normal', 'diabetes'])
plt.hist(x=[df.iloc[:, 6][df.iloc[:,16]==0], df.iloc[:, 6][df.iloc[:,16]==1]], bins=10, histtype='barstacked', label=['normal', 'diabetes'])
# plt.hist(x=[df.iloc[:, 9][df.iloc[:,16]==0], df.iloc[:, 9][df.iloc[:,16]==1]], bins=10, histtype='barstacked', label=['normal', 'diabetes'])
# plt.hist(x=[df.iloc[:, 10][df.iloc[:,16]==0], df.iloc[:, 10][df.iloc[:,16]==1]], bins=10, histtype='barstacked', label=['normal', 'diabetes'])

plt.legend()
